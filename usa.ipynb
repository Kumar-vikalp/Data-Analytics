# %%
import pandas as pd

# %%
usa = pd.read_csv("usa_21.txt", sep='\t', encoding='latin1')

# %%
usa
# Out:
#                                                      name  \
# 0                                     Matthew T Filippini
# 1       , Floor Size - 5,440 sqft Parcel ID# 051711808...
# 2                                       Matthew Filippini
# 3                             ude: 42.0098709, -87.690465
# 4                                     Matthew A Filippini
# ...                                                   ...
# 998845                               Nicola Yvonne Felton
# 998846                      ¢ MI â¢ Detroit MI â¢ 50-60
# 998847                                    Nicola H Felton
# 998848                                                NaN
# 998849                                        Olga Felton
#
#                                                       age  \
# 0                                                      50
# 1                                                     NaN
# 2                                                      57
# ...
